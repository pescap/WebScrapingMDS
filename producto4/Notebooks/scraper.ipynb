# %% [markdown]
# # Bibliotecas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import os
from datetime import date, timedelta
import re

# %% [markdown]
# # Clases y Funciones propias

# %%
class Sismo:
    pass

# %%
def get_data(s):   
    sismos = []
    for i in s:
        if i.find("th", class_="icon-search") is not None:
            #print("buscador")
            next
        elif (i.find("th", text=re.compile(".*Fecha Local / Lugar.*")) is not None):
            #print("header")
            next
        else:
            
            sismo = Sismo()
            sismo.evento = i.find_all('td')[0].text[19:] #Lugar
            sismo.fecha_local = i.find_all('td')[0].text[:19] #Lugar
            sismo.fecha_utc = i.find_all('td')[1].text # Fecha
            sismo.lat = "-" +  i.find_all('td')[2].text.split("-")[1] #Latitud
            sismo.lng = "-" +  i.find_all('td')[2].text.split("-")[2] # Longitud
            sismo.profundidad = i.find_all('td')[3].text # Profundidad
            sismo.magnitud = i.find_all('td')[4].text #Magnitud 
            sismos.append(sismo)
    return pd.DataFrame.from_records([t.__dict__ for t in sismos ])

# %%
def get_source(fecha):
    fecha_data = pd.to_datetime(fecha)
    url = 'https://www.sismologia.cl/sismicidad/catalogo/'+fecha_data.strftime('%Y/%m/%Y%m%d')+'.html'
    print("Ruta_log: ",url)
    ssm = requests.get(url)
    s = BeautifulSoup(ssm.text, 'lxml').find_all('tr')
    return s

# %%
def process_data(df):
    df[["fecha_local", "hora_local"]] = df["fecha_local"].str.split(' ', expand=True)
    df[["fecha_utc", "hora_utc"]] = df["fecha_utc"].str.split(' ', expand=True)
    df[["profundidad", "profundidad_unidad"]] = df["profundidad"].str.split(' ', expand=True)
    df[["magnitud", "magnitud_unidad"]] = df["magnitud"].str.split(' ', expand=True)
    
    return df[['evento', 'lat', 'lng', 'fecha_local', 'hora_local', 
            'fecha_utc', 'hora_utc', 'profundidad', 'profundidad_unidad','magnitud','magnitud_unidad']]

# %%
def get_today_as_string():
    return date.today().strftime("%m/%d/%Y")

# %%
def get_yesterday_as_string():
    yesterday = date.today() - timedelta(days=1)
    return yesterday.strftime("%m/%d/%Y")

# %%
def save_file(df, fecha):
    fecha_data = pd.to_datetime(fecha)
    nombre_archivo = fecha_data.strftime('%Y%m%d') + '_sismos_' + '.csv' 
    file_dir = os.path.dirname(os.path.abspath("__file__"))
    csv_folder = 'output/' + fecha_data.strftime('%Y') + "/" + fecha_data.strftime('%m')
    try:
        os.makedirs(os.path.join(file_dir, csv_folder))
    except FileExistsError:
        pass
    file_path = os.path.join(file_dir, csv_folder, nombre_archivo)
    df.to_csv(file_path, index=False)
    print('Archivo guardado', nombre_archivo)
    print("")

# %%
def process_yesterday():
    #Obtenemos la fecha del día anterior
    yesterday = get_yesterday_as_string()

    #Obtenemos los datos de nuestro sitio
    fuente = get_source(yesterday)

    #Obtenemos los datos en formato dataframe
    df_sismos = get_data(fuente)

    #Procesar datos
    df_sismos = process_data(df_sismos)

    #Guardamos nuestros datos en formato csv
    save_file(df_sismos, yesterday)

# %%
def process_history(date):
    #Obtenemos los datos de nuestro sitio
    fuente = get_source(date)

    #Obtenemos los datos en formato dataframe
    df_sismos = get_data(fuente)

    #Procesar datos
    df_sismos = process_data(df_sismos)

    #Guardamos nuestros datos en formato csv
    save_file(df_sismos, date)

# %%
def create_process_history(fecha_inicio, sleep_time = 2):
    
    #la historia se mide hasta 2 días atras, el día anterior es parte del scraping diario
    fecha_termino = (date.today() - timedelta(days=2)).strftime("%m/%d/%Y") 

    rango_fechas = pd.date_range(start=fecha_inicio, end=fecha_termino)

    for fecha in rango_fechas:
        process_history(fecha.strftime("%m/%d/%Y"))
        sleep(sleep_time)

# %% [markdown]
# # Realizando lectura para ayer
# ### Esta funcion se deberia aislar para ejecutar en el job que implementaremos en GitHub, para capturar los datos del día anterior
# * Opción 1: Generar las llamadas a funciones múltiples funciones

# %%
#Obtenemos la fecha del día anterior
yesterday = get_yesterday_as_string()

#Obtenemos los datos de nuestro sitio
fuente = get_source(yesterday)

#Obtenemos los datos en formato dataframe
df_sismos = get_data(fuente)

#Procesar datos
df_sismos = process_data(df_sismos)

#Guardamos nuestros datos en formato csv
save_file(df_sismos, yesterday)
# Out:
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220828.html
# Archivo guardado 20220828_sismos_.csv

# %% [markdown]
# * Opcion 2: Llamar a una funcion que encapsula todo el proceso anterior

# %%
#Consumimos una la funcion que hace todo el proceso para el día de ayer
process_yesterday()
# Out:
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220828.html
# Archivo guardado 20220828_sismos_.csv

# %% [markdown]
# Como se puede ver, el resultado es el mismo.

# %% [markdown]
# # Procesando la historia
# ### Ahora generaremos un proceso para guardar los datos de la historia que queremos manejar. De esta manera, tendremos un archivo csv por cada día.
# **Nota:** Se considera historia hasta 2 días atras del día de la ejecución. El día anterior debe obtenerse con el proceso automático diario.

# %%
#Se definen las fechas como texto
fecha_inicio = "01/01/2022" #origen desde agosto 2022
create_process_history(fecha_inicio, 2) #Segundo parámetro es el tiempo de sleep para cada día
# Out:
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220101.html
# Archivo guardado 20220101_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220102.html
# Archivo guardado 20220102_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220103.html
# Archivo guardado 20220103_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220104.html
# Archivo guardado 20220104_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220105.html
# Archivo guardado 20220105_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220106.html
# Archivo guardado 20220106_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220107.html
# Archivo guardado 20220107_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220108.html
# Archivo guardado 20220108_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220109.html
# Archivo guardado 20220109_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220110.html
# Archivo guardado 20220110_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220111.html
# Archivo guardado 20220111_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220112.html
# Archivo guardado 20220112_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220113.html
# Archivo guardado 20220113_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220114.html
# Archivo guardado 20220114_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220115.html
# Archivo guardado 20220115_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220116.html
# Archivo guardado 20220116_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220117.html
# Archivo guardado 20220117_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220118.html
# Archivo guardado 20220118_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220119.html
# Archivo guardado 20220119_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220120.html
# Archivo guardado 20220120_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220121.html
# Archivo guardado 20220121_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220122.html
# Archivo guardado 20220122_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220123.html
# Archivo guardado 20220123_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220124.html
# Archivo guardado 20220124_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220125.html
# Archivo guardado 20220125_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220126.html
# Archivo guardado 20220126_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220127.html
# Archivo guardado 20220127_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220128.html
# Archivo guardado 20220128_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220129.html
# Archivo guardado 20220129_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220130.html
# Archivo guardado 20220130_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/01/20220131.html
# Archivo guardado 20220131_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220201.html
# Archivo guardado 20220201_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220202.html
# Archivo guardado 20220202_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220203.html
# Archivo guardado 20220203_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220204.html
# Archivo guardado 20220204_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220205.html
# Archivo guardado 20220205_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220206.html
# Archivo guardado 20220206_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220207.html
# Archivo guardado 20220207_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220208.html
# Archivo guardado 20220208_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220209.html
# Archivo guardado 20220209_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220210.html
# Archivo guardado 20220210_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220211.html
# Archivo guardado 20220211_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220212.html
# Archivo guardado 20220212_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220213.html
# Archivo guardado 20220213_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220214.html
# Archivo guardado 20220214_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220215.html
# Archivo guardado 20220215_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220216.html
# Archivo guardado 20220216_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220217.html
# Archivo guardado 20220217_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220218.html
# Archivo guardado 20220218_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220219.html
# Archivo guardado 20220219_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220220.html
# Archivo guardado 20220220_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220221.html
# Archivo guardado 20220221_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220222.html
# Archivo guardado 20220222_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220223.html
# Archivo guardado 20220223_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220224.html
# Archivo guardado 20220224_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220225.html
# Archivo guardado 20220225_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220226.html
# Archivo guardado 20220226_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220227.html
# Archivo guardado 20220227_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/02/20220228.html
# Archivo guardado 20220228_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220301.html
# Archivo guardado 20220301_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220302.html
# Archivo guardado 20220302_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220303.html
# Archivo guardado 20220303_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220304.html
# Archivo guardado 20220304_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220305.html
# Archivo guardado 20220305_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220306.html
# Archivo guardado 20220306_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220307.html
# Archivo guardado 20220307_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220308.html
# Archivo guardado 20220308_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220309.html
# Archivo guardado 20220309_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220310.html
# Archivo guardado 20220310_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220311.html
# Archivo guardado 20220311_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220312.html
# Archivo guardado 20220312_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220313.html
# Archivo guardado 20220313_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220314.html
# Archivo guardado 20220314_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220315.html
# Archivo guardado 20220315_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220316.html
# Archivo guardado 20220316_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220317.html
# Archivo guardado 20220317_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220318.html
# Archivo guardado 20220318_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220319.html
# Archivo guardado 20220319_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220320.html
# Archivo guardado 20220320_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220321.html
# Archivo guardado 20220321_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220322.html
# Archivo guardado 20220322_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220323.html
# Archivo guardado 20220323_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220324.html
# Archivo guardado 20220324_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220325.html
# Archivo guardado 20220325_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220326.html
# Archivo guardado 20220326_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220327.html
# Archivo guardado 20220327_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220328.html
# Archivo guardado 20220328_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220329.html
# Archivo guardado 20220329_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220330.html
# Archivo guardado 20220330_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/03/20220331.html
# Archivo guardado 20220331_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220401.html
# Archivo guardado 20220401_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220402.html
# Archivo guardado 20220402_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220403.html
# Archivo guardado 20220403_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220404.html
# Archivo guardado 20220404_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220405.html
# Archivo guardado 20220405_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220406.html
# Archivo guardado 20220406_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220407.html
# Archivo guardado 20220407_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220408.html
# Archivo guardado 20220408_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220409.html
# Archivo guardado 20220409_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220410.html
# Archivo guardado 20220410_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220411.html
# Archivo guardado 20220411_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220412.html
# Archivo guardado 20220412_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220413.html
# Archivo guardado 20220413_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220414.html
# Archivo guardado 20220414_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220415.html
# Archivo guardado 20220415_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220416.html
# Archivo guardado 20220416_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220417.html
# Archivo guardado 20220417_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220418.html
# Archivo guardado 20220418_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220419.html
# Archivo guardado 20220419_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220420.html
# Archivo guardado 20220420_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220421.html
# Archivo guardado 20220421_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220422.html
# Archivo guardado 20220422_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220423.html
# Archivo guardado 20220423_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220424.html
# Archivo guardado 20220424_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220425.html
# Archivo guardado 20220425_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220426.html
# Archivo guardado 20220426_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220427.html
# Archivo guardado 20220427_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220428.html
# Archivo guardado 20220428_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220429.html
# Archivo guardado 20220429_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/04/20220430.html
# Archivo guardado 20220430_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220501.html
# Archivo guardado 20220501_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220502.html
# Archivo guardado 20220502_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220503.html
# Archivo guardado 20220503_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220504.html
# Archivo guardado 20220504_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220505.html
# Archivo guardado 20220505_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220506.html
# Archivo guardado 20220506_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220507.html
# Archivo guardado 20220507_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220508.html
# Archivo guardado 20220508_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220509.html
# Archivo guardado 20220509_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220510.html
# Archivo guardado 20220510_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220511.html
# Archivo guardado 20220511_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220512.html
# Archivo guardado 20220512_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220513.html
# Archivo guardado 20220513_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220514.html
# Archivo guardado 20220514_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220515.html
# Archivo guardado 20220515_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220516.html
# Archivo guardado 20220516_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220517.html
# Archivo guardado 20220517_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220518.html
# Archivo guardado 20220518_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220519.html
# Archivo guardado 20220519_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220520.html
# Archivo guardado 20220520_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220521.html
# Archivo guardado 20220521_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220522.html
# Archivo guardado 20220522_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220523.html
# Archivo guardado 20220523_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220524.html
# Archivo guardado 20220524_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220525.html
# Archivo guardado 20220525_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220526.html
# Archivo guardado 20220526_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220527.html
# Archivo guardado 20220527_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220528.html
# Archivo guardado 20220528_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220529.html
# Archivo guardado 20220529_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220530.html
# Archivo guardado 20220530_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/05/20220531.html
# Archivo guardado 20220531_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220601.html
# Archivo guardado 20220601_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220602.html
# Archivo guardado 20220602_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220603.html
# Archivo guardado 20220603_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220604.html
# Archivo guardado 20220604_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220605.html
# Archivo guardado 20220605_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220606.html
# Archivo guardado 20220606_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220607.html
# Archivo guardado 20220607_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220608.html
# Archivo guardado 20220608_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220609.html
# Archivo guardado 20220609_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220610.html
# Archivo guardado 20220610_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220611.html
# Archivo guardado 20220611_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220612.html
# Archivo guardado 20220612_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220613.html
# Archivo guardado 20220613_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220614.html
# Archivo guardado 20220614_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220615.html
# Archivo guardado 20220615_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220616.html
# Archivo guardado 20220616_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220617.html
# Archivo guardado 20220617_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220618.html
# Archivo guardado 20220618_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220619.html
# Archivo guardado 20220619_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220620.html
# Archivo guardado 20220620_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220621.html
# Archivo guardado 20220621_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220622.html
# Archivo guardado 20220622_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220623.html
# Archivo guardado 20220623_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220624.html
# Archivo guardado 20220624_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220625.html
# Archivo guardado 20220625_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220626.html
# Archivo guardado 20220626_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220627.html
# Archivo guardado 20220627_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220628.html
# Archivo guardado 20220628_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220629.html
# Archivo guardado 20220629_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/06/20220630.html
# Archivo guardado 20220630_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220701.html
# Archivo guardado 20220701_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220702.html
# Archivo guardado 20220702_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220703.html
# Archivo guardado 20220703_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220704.html
# Archivo guardado 20220704_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220705.html
# Archivo guardado 20220705_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220706.html
# Archivo guardado 20220706_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220707.html
# Archivo guardado 20220707_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220708.html
# Archivo guardado 20220708_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220709.html
# Archivo guardado 20220709_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220710.html
# Archivo guardado 20220710_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220711.html
# Archivo guardado 20220711_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220712.html
# Archivo guardado 20220712_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220713.html
# Archivo guardado 20220713_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220714.html
# Archivo guardado 20220714_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220715.html
# Archivo guardado 20220715_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220716.html
# Archivo guardado 20220716_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220717.html
# Archivo guardado 20220717_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220718.html
# Archivo guardado 20220718_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220719.html
# Archivo guardado 20220719_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220720.html
# Archivo guardado 20220720_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220721.html
# Archivo guardado 20220721_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220722.html
# Archivo guardado 20220722_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220723.html
# Archivo guardado 20220723_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220724.html
# Archivo guardado 20220724_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220725.html
# Archivo guardado 20220725_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220726.html
# Archivo guardado 20220726_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220727.html
# Archivo guardado 20220727_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220728.html
# Archivo guardado 20220728_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220729.html
# Archivo guardado 20220729_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220730.html
# Archivo guardado 20220730_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/07/20220731.html
# Archivo guardado 20220731_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220801.html
# Archivo guardado 20220801_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220802.html
# Archivo guardado 20220802_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220803.html
# Archivo guardado 20220803_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220804.html
# Archivo guardado 20220804_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220805.html
# Archivo guardado 20220805_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220806.html
# Archivo guardado 20220806_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220807.html
# Archivo guardado 20220807_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220808.html
# Archivo guardado 20220808_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220809.html
# Archivo guardado 20220809_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220810.html
# Archivo guardado 20220810_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220811.html
# Archivo guardado 20220811_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220812.html
# Archivo guardado 20220812_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220813.html
# Archivo guardado 20220813_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220814.html
# Archivo guardado 20220814_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220815.html
# Archivo guardado 20220815_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220816.html
# Archivo guardado 20220816_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220817.html
# Archivo guardado 20220817_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220818.html
# Archivo guardado 20220818_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220819.html
# Archivo guardado 20220819_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220820.html
# Archivo guardado 20220820_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220821.html
# Archivo guardado 20220821_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220822.html
# Archivo guardado 20220822_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220823.html
# Archivo guardado 20220823_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220824.html
# Archivo guardado 20220824_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220825.html
# Archivo guardado 20220825_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220826.html
# Archivo guardado 20220826_sismos_.csv
#
# Ruta_log:  https://www.sismologia.cl/sismicidad/catalogo/2022/08/20220827.html
# Archivo guardado 20220827_sismos_.csv
