# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
import pandas as pd
from pandas import Series, DataFrame
from pandas import ExcelWriter
from pandas import ExcelFile
from bs4 import BeautifulSoup
from textblob import TextBlob
import textblob

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# alabaster                     0.7.12
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# asttokens                     2.0.5
# atomicwrites                  1.4.0
# attrs                         21.4.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# bcrypt                        3.2.0
# beautifulsoup4                4.11.1
# binaryornot                   0.4.4
# black                         22.6.0
# bleach                        4.1.0
# blinker                       1.4
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# certifi                       2022.6.15
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.0.0
# colorama                      0.4.5
# colorlog                      6.6.0
# cookiecutter                  1.7.3
# cryptography                  37.0.1
# cycler                        0.11.0
# debugpy                       1.5.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.4
# docutils                      0.18.1
# easydev                       0.12.0
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.15.1
# fitter                        1.2.3
# flake8                        4.0.1
# fonttools                     4.25.0
# idna                          3.3
# imagesize                     1.4.1
# imbalanced-learn              0.9.1
# importlib-metadata            4.11.3
# importlib-resources           5.2.0
# inflection                    0.5.1
# intervaltree                  3.1.0
# ipykernel                     6.9.1
# ipython                       7.31.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# isort                         5.9.3
# jedi                          0.18.1
# jellyfish                     0.9.0
# Jinja2                        3.0.3
# jinja2-time                   0.2.0
# joblib                        1.1.0
# jsonschema                    4.4.0
# jupyter-client                7.2.2
# jupyter-core                  4.10.0
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            1.0.0
# keyring                       23.4.0
# kiwisolver                    1.4.2
# lazy-object-proxy             1.6.0
# lxml                          4.8.0
# MarkupSafe                    2.1.1
# matplotlib                    3.5.1
# matplotlib-inline             0.1.2
# mccabe                        0.6.1
# missingno                     0.4.2
# mistune                       0.8.4
# mixed-naive-bayes             0.0.3
# mizani                        0.7.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mpmath                        1.2.1
# munkres                       1.1.4
# mypy-extensions               0.4.3
# nbclient                      0.5.13
# nbconvert                     6.4.4
# nbformat                      5.3.0
# nest-asyncio                  1.5.5
# nltk                          3.6.7
# notebook                      6.4.12
# numexpr                       2.8.3
# numpy                         1.22.3
# numpydoc                      1.4.0
# oauthlib                      3.2.0
# openpyxl                      3.0.9
# packaging                     21.3
# palettable                    3.3.0
# pandas                        1.4.3
# pandocfilters                 1.5.0
# paramiko                      2.8.1
# parso                         0.8.3
# pathspec                      0.9.0
# patsy                         0.5.2
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.1.2
# platformdirs                  2.4.0
# plotly                        5.9.0
# plotnine                      0.0.0
# pluggy                        1.0.0
# ply                           3.11
# poyo                          0.5.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.20
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# pycodestyle                   2.8.0
# pycparser                     2.21
# pydocstyle                    6.1.1
# pyflakes                      2.4.0
# Pygments                      2.11.2
# PyJWT                         2.4.0
# pylint                        2.14.5
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.4
# PyQt5                         5.15.7
# PyQt5-sip                     12.11.0
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-dotenv                 0.20.0
# python-lsp-black              1.0.0
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.3.3
# python-slugify                5.0.2
# pytz                          2022.1
# pywin32                       302
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.2
# PyYAML                        6.0
# pyzmq                         23.2.0
# QDarkStyle                    3.0.2
# qstylizer                     0.1.10
# QtAwesome                     1.0.3
# qtconsole                     5.2.2
# QtPy                          2.0.1
# regex                         2022.8.17
# requests                      2.28.1
# requests-oauthlib             1.3.1
# rope                          0.22.0
# Rtree                         0.9.7
# scikit-learn                  1.1.2
# scipy                         1.7.3
# seaborn                       0.11.2
# selenium                      3.141.0
# Send2Trash                    1.8.0
# setuptools                    63.4.1
# sip                           6.6.2
# six                           1.16.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.3.1
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.2.2
# spyder-kernels                2.2.1
# stack-data                    0.2.0
# statsmodels                   0.13.2
# sympy                         1.10.1
# tenacity                      8.0.1
# terminado                     0.13.1
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.15.3
# textdistance                  4.2.1
# threadpoolctl                 2.2.0
# three-merge                   0.1.1
# tinycss                       0.4
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# tornado                       6.1
# tqdm                          4.64.0
# traitlets                     5.1.1
# tweepy                        4.10.1
# typing_extensions             4.3.0
# ujson                         5.4.0
# Unidecode                     1.2.0
# urllib3                       1.26.11
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webdriver-manager             3.8.3
# webencodings                  0.5.1
# wheel                         0.37.1
# widgetsnbextension            3.5.2
# win-inet-pton                 1.1.0
# wincertstore                  0.2
# wrapt                         1.14.1
# yapf                          0.31.0
# zipp                          3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
driver = webdriver.Chrome()

link = 'https://finance.yahoo.com/topic/stock-market-news/'

driver.get(link)
driver.maximize_window()

for i in range(1,15):
    driver.execute_script("window.scrollBy(0, 10000);")
    time.sleep(5)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
print("Ingrese palabra a scrapear")
nombre = input()      

news_list = []

# Encontrar todos los headers en finance.yahoo
for h in soup.findAll('h3',class_='Mb(5px)'):
    news_title = h.findAll()[0].text

    if news_title not in news_list:
        if 'ad' not in news_title:
            news_list.append(news_title)


no_of_news = 0
keyword_list = []
    # Recorre la lista y busca la palabra clave
for i, title in enumerate(news_list):
    text = ''
    if nombre.lower() in title:
        text = ' <------------ Palabra clave'
        no_of_news += 1
        keyword_list.append(title)

    print(i + 1, ':', title, text)

    # Print de Titulos de los artulos que contienen los keywords
print(f'\n--------- Total menciones de "{nombre}" = {no_of_news} ---------')
for i, title in enumerate(keyword_list):
    print(i + 1, ':', title)
# Out:
# Ingrese palabra a scrapear
# stock
# 1 : GLOBAL MARKETS-Stocks slide, dollar spikes as September starts stormy
# 2 : US STOCKS-Wall Street slides for fifth straight day on rate hike jitters
# 3 : UK hedge fund founder charged in New York with market manipulation, fraud
# 4 : Semtech Stock Tanks After Chipmaker Whiffs On Guidance
# 5 : CANADA STOCKS-TSX falls to its lowest in five weeks as energy, material stocks tumble  <------------ Palabra clave
# 6 : Semiconductor Stocks Fall on US Export Restrictions
# 7 : Stock market news live updates: Stocks extend losses in downbeat start to September
# 8 : EMERGING MARKETS-Currencies slide as strong U.S. manufacturing spurs dollar
# 9 : Nvidia stock hits new 52-week low amid U.S. export ban news  <------------ Palabra clave
# 10 : Nvidia and AMD Stock Tumble as U.S. Limits Exports to China
# 11 : 'Brutal' housing prices hit America's Zoom towns – markets once flourishing in the pandemic
# 12 : Dow Jones Falls As Yields Jump; Steel, Energy, EV Stocks Slide; Apple Test Key Level
# 13 : Little-Known Chinese Stock Plunges After Mystery 13,000% Rally
# 14 : Ciena Stock Slides as Parts Shortage Hits Sales
# 15 : Bed Bath & Beyond stock falls again as another analyst turns bearish, citing ‘abysmal’ business trends  <------------ Palabra clave
# 16 : Nutanix Stock Is Soaring. Wall Street Likes the Upbeat Outlook.
# 17 : The launch of a K-Pop ETF continues the Wall Street trend of offering super niche thematic fund strategies to investors
# 18 : Industry Moves: New Balance Names Global Director of International Marketing + More News
# 19 : ‘Vulnerable time for the housing market’: Mortgage rates rise to 5.66%, double what they were a year ago, and will likely slow house-price appreciation
# 20 : Dow Falls to Start September, Nvidia Slides—and What Else Is Happening in the Stock Market Today
# 21 : Dow Jones Falls Amid Key Economic Data; AMD, Nvidia Tumble On Government Restrictions
# 22 : Legendary investor Jeremy Grantham flags an unprecedented 'superbubble' in markets, warns it's about to burst, and lays out why it's so dangerous in a new research note. Here are the 7 best quotes.
# 23 : Okta Second Quarter Results Beat Estimates But Stock Tumbles
# 24 : Nvidia and other chip stocks fall as US restricts sales to China and Russia over concerns of military use  <------------ Palabra clave
# 25 : WRAPUP 1-U.S. weekly jobless claims at two-month low as labor market stays resilient
# 26 : 2 “Strong Buy” Dividend Stocks With at Least 8% Dividend Yield
# 27 : Jeremy Grantham warns the 'superbubble' in stocks is entering its final stages and is soon set for an 'epic finale'  <------------ Palabra clave
# 28 : Stocks are set to retest June lows in a 'torrid' autumn for the market as corporate earnings revisions roll in, JPMorgan Asset Management global strategy chief says
# 111 : ‘Should I wait until the market calms down or pull the trigger now?’ I’m tired of my brokerage charging 1%, and I want to move my money now, but don’t want to lock in losses. What’s my move?
# 112 : Nvidia Stock Tumbles As US Bans AI Chip Sales To China Clients: AMD Also Hit By New Export Rules
# 113 : Best Income Stocks to Buy for September 1st
# 114 : EMERGING MARKETS-Currencies, stocks sell-off as investors brace for tightening  <------------ Palabra clave
# 115 : European markets watchdog on red alert for Ukraine war contagion
# 116 : GLOBAL MARKETS-Stocks slide, dollar spikes as September starts with a bump
# 117 : Analysts Are Too Optimistic on European Stocks, Citi Strategists Say
# 118 : Buy This Cheap Dividend Stock for Value, Growth and Upside?
# 119 : Man Group Says Asia Stocks Will Be First to Emerge From Downturn
# 120 : UPDATE 2-OPEC+ JTC's base case sees 300,000 bpd market deficit in 2023
# 121 : Russian stocks ease from recent highs, rouble edges towards 60 vs dollar  <------------ Palabra clave
# 122 : Australia shares end at 5-week low as miners, gold stocks weigh  <------------ Palabra clave
# 123 : OPEC+ JTC's base case sees market deficit of 300,000 bpd in 2023 -document
# 124 : ISM & Jobless Claims, China Lockdown, NVIDIA Warning - What's Moving Markets
# 125 : Market Timers, Beware: Now Isn’t the Time to Buy the Dip
# 126 : Centrica, SSE Buck Falling Market as Truss Says No to Windfall Taxes
# 127 : September Could Be Even Worse for Stocks. How to Survive the Downturn.
# 128 : European Stocks Sharply Lower; German Retail Sales Fail to Lift Gloom
# 129 : Asian markets track Wall Street’s slide on expected rate raises
#
# --------- Total menciones de "stock" = 17 ---------
# 1 : CANADA STOCKS-TSX falls to its lowest in five weeks as energy, material stocks tumble
# 2 : Nvidia stock hits new 52-week low amid U.S. export ban news
# 3 : Bed Bath & Beyond stock falls again as another analyst turns bearish, citing ‘abysmal’ business trends
# 4 : Nvidia and other chip stocks fall as US restricts sales to China and Russia over concerns of military use
# 5 : Jeremy Grantham warns the 'superbubble' in stocks is entering its final stages and is soon set for an 'epic finale'
# 6 : Global stocks extend falls into new month on darkening outlook
# 7 : The bear market in stocks has a long way to go, this money manager warns. Here are the 2 strategic moves he’s making.
# 8 : Toro stock slips after profit beats views but sales comes up shy, as supply constraints weigh
# 9 : Am I a fool for keeping my IRA invested in stocks?
# 10 : Ciena stock tumbles after profit and sales miss expectations, with component supply issues expected to continue
# 11 : Signet Jewelers stock surges after profit beats expectations, upbeat full-year outlook affirmed
# 12 : What history says about September and the stock market after summer bounce runs out of steam
# 13 : Hormel Foods stock drops after profit miss and outlook lowered, while sales guidance was raised
# 14 : NIO, other China-based EV maker stocks fall after August deliveries reports
# 15 : EMERGING MARKETS-Currencies, stocks sell-off as investors brace for tightening
# 16 : Russian stocks ease from recent highs, rouble edges towards 60 vs dollar
# 17 : Australia shares end at 5-week low as miners, gold stocks weigh

# %%
from textblob import TextBlob
keyword_list

news_sentblob = []
for news in keyword_list:
	print(news)
	analysis = TextBlob(news)
	print(analysis.sentiment)
	news_sentblob.append((news, analysis.sentiment[0], analysis.sentiment[1]))
# Out:
# CANADA STOCKS-TSX falls to its lowest in five weeks as energy, material stocks tumble
# Sentiment(polarity=0.0, subjectivity=0.0)
# Nvidia stock hits new 52-week low amid U.S. export ban news
# Sentiment(polarity=0.06818181818181818, subjectivity=0.37727272727272726)
# Bed Bath & Beyond stock falls again as another analyst turns bearish, citing ‘abysmal’ business trends
# Sentiment(polarity=0.0, subjectivity=0.0)
# Nvidia and other chip stocks fall as US restricts sales to China and Russia over concerns of military use
# Sentiment(polarity=-0.1125, subjectivity=0.2375)
# Jeremy Grantham warns the 'superbubble' in stocks is entering its final stages and is soon set for an 'epic finale'
# Sentiment(polarity=0.05, subjectivity=0.7)
# Global stocks extend falls into new month on darkening outlook
# Sentiment(polarity=0.06818181818181818, subjectivity=0.22727272727272727)
# The bear market in stocks has a long way to go, this money manager warns. Here are the 2 strategic moves he’s making.
# Sentiment(polarity=-0.05, subjectivity=0.4)
# Toro stock slips after profit beats views but sales comes up shy, as supply constraints weigh
# Sentiment(polarity=-0.5, subjectivity=0.5)
# Am I a fool for keeping my IRA invested in stocks?
# Sentiment(polarity=0.0, subjectivity=0.0)
# Ciena stock tumbles after profit and sales miss expectations, with component supply issues expected to continue
# Sentiment(polarity=-0.1, subjectivity=0.4)
# Signet Jewelers stock surges after profit beats expectations, upbeat full-year outlook affirmed
# Sentiment(polarity=0.0, subjectivity=0.0)
# What history says about September and the stock market after summer bounce runs out of steam
# Sentiment(polarity=0.0, subjectivity=0.0)
# Hormel Foods stock drops after profit miss and outlook lowered, while sales guidance was raised
# Sentiment(polarity=0.0, subjectivity=0.0)
# NIO, other China-based EV maker stocks fall after August deliveries reports
# Sentiment(polarity=-0.125, subjectivity=0.375)
# EMERGING MARKETS-Currencies, stocks sell-off as investors brace for tightening
# Sentiment(polarity=0.0, subjectivity=0.0)
# Russian stocks ease from recent highs, rouble edges towards 60 vs dollar
# Sentiment(polarity=0.0, subjectivity=0.125)
# Australia shares end at 5-week low as miners, gold stocks weigh
# Sentiment(polarity=0.0, subjectivity=0.3)

# %%
news_sentblob
# Out:
# [('CANADA STOCKS-TSX falls to its lowest in five weeks as energy, material stocks tumble',
#   0.0,
#   0.0),
#  ('Nvidia stock hits new 52-week low amid U.S. export ban news',
#   0.06818181818181818,
#   0.37727272727272726),
#  ('Bed Bath & Beyond stock falls again as another analyst turns bearish, citing ‘abysmal’ business trends',
#   0.0,
#   0.0),
#  ('Nvidia and other chip stocks fall as US restricts sales to China and Russia over concerns of military use',
#   -0.1125,
#   0.2375),
#  ("Jeremy Grantham warns the 'superbubble' in stocks is entering its final stages and is soon set for an 'epic finale'",
#   0.05,
#   0.7),
#  ('Global stocks extend falls into new month on darkening outlook',
#   0.06818181818181818,
#   0.22727272727272727),
#  ('The bear market in stocks has a long way to go, this money manager warns. Here are the 2 strategic moves he’s making.',
#   -0.05,
#   0.4),
#  ('Toro stock slips after profit beats views but sales comes up shy, as supply constraints weigh',
#   -0.5,
#   0.5),
#  ('Am I a fool for keeping my IRA invested in stocks?', 0.0, 0.0),
#  ('Ciena stock tumbles after profit and sales miss expectations, with component supply issues expected to continue',
#   -0.1,
#   0.4),
#  ('Signet Jewelers stock surges after profit beats expectations, upbeat full-year outlook affirmed',
#   0.0,
#   0.0),
#  ('What history says about September and the stock market after summer bounce runs out of steam',
#   0.0,
#   0.0),
#  ('Hormel Foods stock drops after profit miss and outlook lowered, while sales guidance was raised',
#   0.0,
#   0.0),
#  ('NIO, other China-based EV maker stocks fall after August deliveries reports',
#   -0.125,
#   0.375),
#  ('EMERGING MARKETS-Currencies, stocks sell-off as investors brace for tightening',
#   0.0,
#   0.0),
#  ('Russian stocks ease from recent highs, rouble edges towards 60 vs dollar',
#   0.0,
#   0.125),
#  ('Australia shares end at 5-week low as miners, gold stocks weigh', 0.0, 0.3)]

# %%
dfb = pd.DataFrame(news_sentblob, columns=['news','polaridad','subjetividad'])

# %%
dfb
# Out:
#                                                  news  polaridad  subjetividad
# 0   CANADA STOCKS-TSX falls to its lowest in five ...   0.000000      0.000000
# 1   Nvidia stock hits new 52-week low amid U.S. ex...   0.068182      0.377273
# 2   Bed Bath & Beyond stock falls again as another...   0.000000      0.000000
# 3   Nvidia and other chip stocks fall as US restri...  -0.112500      0.237500
# 4   Jeremy Grantham warns the 'superbubble' in sto...   0.050000      0.700000
# 5   Global stocks extend falls into new month on d...   0.068182      0.227273
# 6   The bear market in stocks has a long way to go...  -0.050000      0.400000
# 7   Toro stock slips after profit beats views but ...  -0.500000      0.500000
# 8   Am I a fool for keeping my IRA invested in sto...   0.000000      0.000000
# 9   Ciena stock tumbles after profit and sales mis...  -0.100000      0.400000
# 10  Signet Jewelers stock surges after profit beat...   0.000000      0.000000
# 11  What history says about September and the stoc...   0.000000      0.000000
# 12  Hormel Foods stock drops after profit miss and...   0.000000      0.000000
# 13  NIO, other China-based EV maker stocks fall af...  -0.125000      0.375000
# 14  EMERGING MARKETS-Currencies, stocks sell-off a...   0.000000      0.000000
# 15  Russian stocks ease from recent highs, rouble ...   0.000000      0.125000
# 16  Australia shares end at 5-week low as miners, ...   0.000000      0.300000

# %%
# Exportar a csv

dfb.to_csv('base1.csv')

# %%
pip install vadersentiment
# Out:
# Requirement already satisfied: vadersentiment in c:\users\rfche\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: requests in c:\users\rfche\anaconda3\lib\site-packages (from vadersentiment) (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rfche\anaconda3\lib\site-packages (from requests->vadersentiment) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\rfche\anaconda3\lib\site-packages (from requests->vadersentiment) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\rfche\anaconda3\lib\site-packages (from requests->vadersentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\rfche\anaconda3\lib\site-packages (from requests->vadersentiment) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
vs = analyzer.polarity_scores("This table is black")
print(vs)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
#news_keyword
#news_sentblob = news


for news in news_sentblob:
	print(news)
	analysis = analyzer.polarity_scores("news")
	print(analysis)
	news_sentblob.append((news, analysis))
# Out:
# ((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((('h', 0.5, 0.5), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}), {'neg': 0.0, 'n ...
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-7581c173d702> in <module>
#       7         analysis = analyzer.polarity_scores("news")
#       8         print(analysis)
# ----> 9         news_sentblob.append((news, analysis))
#      10
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
## Se exporta lista news_sentblob a base2.csv

import csv

# %%
with open('base2.csv', 'w', newline='') as file:
    writer = csv.writer(file, quoting=csv.QUOTE_ALL,delimiter=';')
    writer.writerows(news_sentblob)
